# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import zipfile
import os

os.makedirs("/content/various_sentences/", exist_ok=True)
# from https://www.kaggle.com/datasets/naseralqaydeh/named-entity-recognition-ner-corpus/
# locally NLP/datasets/partial_datasets/ner.csv.zip

with zipfile.ZipFile("/content/drive/MyDrive/Datasets/NLP/ner.csv.zip", "r") as zf:
  zf.extractall("/content/various_sentences/")

# %%
import pandas as pd
import ast

# read csv to df 
def load_csv_data(data_path):
    df = pd.read_csv(data_path)
    df.dropna(inplace=True)
    print("Number of rows : ",df.shape[0]," and the number of columns : ",df.shape[1])
    return df

ner_df = load_csv_data("/content/various_sentences/ner.csv")
# necessary to convert to usable format for df
def preprocess_ner_df(df):
    for i in range(len(df)):
        pos = ast.literal_eval(df.loc[i, 'POS'])
        tags = ast.literal_eval(df.loc[i, 'Tag'])
        df.loc[i, 'POS'] = [str(word) for word in pos]
        df.loc[i, 'Tag'] = [str(word.upper()) for word in tags]
    return df

ner_df = preprocess_ner_df(ner_df)
# i need only sentences, annotations
ner_df = ner_df[['Sentence','Tag']]

ner_df.head()
# Out:
# Number of rows :  47959  and the number of columns :  4
#                                             Sentence  \
# 0  Thousands of demonstrators have marched throug...
# 1  Families of soldiers killed in the conflict jo...
# 2  They marched from the Houses of Parliament to ...
# 3  Police put the number of marchers at 10,000 wh...
# 4  The protest comes on the eve of the annual con...
#
#                                                  Tag
# 0  [O, O, O, O, O, O, B-GEO, O, O, O, O, O, B-GEO...
# 1  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2  [O, O, O, O, O, O, O, O, O, O, O, B-GEO, I-GEO...
# 3      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O]
# 4  [O, O, O, O, O, O, O, O, O, O, O, B-GEO, O, O,...

# %%
tag_values = list(ner_df.Tag.values)
sentences = list(ner_df.Sentence.values)
del ner_df
print(tag_values[:5])
print(sentences[:5])
# Out:
# [['O', 'O', 'O', 'O', 'O', 'O', 'B-GEO', 'O', 'O', 'O', 'O', 'O', 'B-GEO', 'O', 'O', 'O', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GEO', 'I-GEO', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GEO', 'O', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'B-GEO', 'O']]
# ['Thousands of demonstrators have marched through London to protest the war in Iraq and demand the withdrawal of British troops from that country .', 'Families of soldiers killed in the conflict joined the protesters who carried banners with such slogans as " Bush Number One Terrorist " and " Stop the Bombings . "', 'They marched from the Houses of Parliament to a rally in Hyde Park .', 'Police put the number of marchers at 10,000 while organizers claimed it was 1,00,000 .', "The protest comes on the eve of the annual conference of Britain 's ruling Labor Party in the southern English seaside resort of Brighton ."]

# %%
unique_tags = set([tag for subl in tag_values for tag in subl])
print(unique_tags)
# Out:
# {'I-TIM', 'B-GPE', 'B-GEO', 'I-GEO', 'I-PER', 'B-EVE', 'I-EVE', 'B-ORG', 'B-TIM', 'O', 'B-PER', 'I-ORG', 'I-ART', 'B-NAT', 'I-NAT', 'I-GPE', 'B-ART'}

# %% [markdown]
#     geo = Geographical Entity
#
#     org = Organization
#
#     per = Person
#
#     gpe = Geopolitical Entity
#
#     tim = Time indicator
#
#     art = Artifact
#
#     eve = Event
#
#     nat = Natural Phenomenon

# %%
non_geo_sentences = []
#obviously exclude GEO
for tag_l, sentence in zip(tag_values, sentences):
  if 'I-GEO' in tag_l or 'B-GEO' in tag_l:
    continue
  else:
    non_geo_sentences.append(sentence)

# %%
del tag_values
del sentences
print(len(non_geo_sentences))
# Out:
# 23548

# %%
import random

# already know how much samples i need -> sample to reduce resource usage
random.shuffle(non_geo_sentences)
non_geo_sentences = random.sample(non_geo_sentences, 16000)

# %%
import re
import random
import math
from transformers import BertTokenizerFast
import json

tokenizer = BertTokenizerFast.from_pretrained("bert-base-cased")

def tokenize_and_label_regular(tokenizer, sentence, tokens, labels):
    for word in sentence.strip().split():
        tokenized_word = tokenizer.tokenize(word)
        tokens.extend(tokenized_word)
        labels.extend(["O"] * len(tokenized_word))

def process_sentence(sentence):
    tokens, labels = [], []
    tokenize_and_label_regular(tokenizer, sentence, tokens, labels)
    return tokens, labels

def process_entry(entry):
    tokens, labels = process_sentence(entry)
    return (tokens, labels)

non_mount_data = []
for entry in non_geo_sentences:
  if entry:
    non_mount_data.append(process_entry(entry))
del non_geo_sentences
random.shuffle(non_mount_data)

# %%
print(non_mount_data[:5])
# Out:
# [(['Sal', '##azar', 'said', 'the', 'End', '##anger', '##ed', 'Species', 'Act', 'was', 'not', 'the', '"', 'proper', 'mechanism', '"', 'for', 'dealing', 'with', 'climate', 'change', 'and', 'said', 'a', 'more', 'comprehensive', 'strategy', 'is', 'needed', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['The', 'government', 'has', 'requested', 'assistance', 'from', 'the', 'I', '##MF', 'and', 'from', 'the', 'African', 'Development', 'Bank', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['They', 'spent', 'a', 'night', 'in', 'jail', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O']), (['U', '.', 'S', '.', 'Secretary', 'of', 'State', 'Con', '##do', '##lee', '##zza', 'Rice', 'says', 'Israeli', 'and', 'Palestinian', 'representatives', 'are', 'discussing', 'peace', 'initiatives', 'behind', 'closed', 'doors', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']), (['C', '##rack', '##s', 'in', 'some', 'of', 'the', 'metal', 'supports', 'of', 'Discovery', "'", 's', 'fuel', 'tank', 'were', 'discovered', 'when', 'a', 'hydrogen', 'leak', 'led', 'NASA', 'to', 'cancel', 'a', 'planned', 'launch', 'attempt', 'in', 'early', 'November', '.'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'])]

# %%
os.makedirs("/content/synthetic/")
os.makedirs("/content/confusing_synthetic/")

# same as in NLP/datasets/partial_datasets/synthetic_batch_1.zip
with zipfile.ZipFile("/content/drive/MyDrive/Datasets/NLP/synthetic_batch1.zip", "r") as zf:
  zf.extractall("/content/synthetic/")

# same as in NLP/datasets/partial_datasets/confusing_synthetic.zip
with zipfile.ZipFile("/content/drive/MyDrive/Datasets/NLP/confusing_synthetic.zip", "r") as zf:
  zf.extractall("/content/confusing_synthetic/")

# same as in NLP/datasets/partial_datasets/synthetic_batch_2.zip
with zipfile.ZipFile("/content/drive/MyDrive/Datasets/NLP/synthetic_batch2.zip", "r") as zf:
  zf.extractall("/content/synthetic_batch2/")

# %%
import json

# elevations in sentences - separated by ||:
# It was only a week since Jack climbed ||Big Bell Mountain|| and now he is heading to the ||Japanese Alps|| for the next mountain on his list.

# for each 10 sentences (output from Llama) we need to extract such elevations
# if extracted name equals to given in prompt - it's mountain, otherwise - elevation (range, plateau)

# distortions - need to be handled like 's in: Kilimanjaro's snow-capped peaks are famous worldwide. 

def get_v_bar_start_indexes(string):
    """Find starting indexes of double vertical bars (||) in the string."""
    return [match.start() for match in re.finditer(r'\|\|', string)]

def check_acceptable_distortion(entity_with_markers, entity_name, is_conf):
    acceptable_distortions = [entity_name + "'s", entity_name + ",", entity_name + "'s,", entity_name + ".", entity_name]
    if is_conf:
        acceptable_distortions += [entity_name.split()[1]] if len(entity_name.split()) > 1 else []
    return entity_with_markers in acceptable_distortions

def tokenize_and_label_regular(tokenizer, sentence, tokens, labels):
    for word in sentence.strip().split():
        tokenized_word = tokenizer.tokenize(word)
        tokens.extend(tokenized_word)
        labels.extend(["O"] * len(tokenized_word))

def tokenize_and_label_elevation(tokenizer, string, tokens, labels, entity_name, is_conf):
    entity = re.sub(r"\|\|", "", string).strip()
    tokenized_entity = tokenizer.tokenize(entity)
    if check_acceptable_distortion(entity, entity_name, is_conf):
        for i, token in enumerate(tokenized_entity):
            if token in {"'s", ",", "."}:
                tokens.append(token)
                labels.append("O")
            else:
                tokens.append(token)
                labels.append("B-MOUNTAIN" if i == 0 else "I-MOUNTAIN")
    else:
        tokens.extend(tokenized_entity)
        labels.extend(["B-ELEVATION"] + ["I-ELEVATION"] * (len(tokenized_entity) - 1))

def process_sentence(sentence, entity_name, is_conf):
    tokens, labels = [], []
    entity_name = entity_name.strip()
    v_bar_starting_indexes = get_v_bar_start_indexes(sentence)

    if len(v_bar_starting_indexes) % 2 != 0:
        print(f"Error: Uneven count of bars in sentence: {sentence}")
        return None

    left = 0
    for i in range(0, len(v_bar_starting_indexes), 2):
        start, end = v_bar_starting_indexes[i], v_bar_starting_indexes[i + 1] + 2
        if left < start:
            tokenize_and_label_regular(tokenizer, sentence[left:start], tokens, labels)
        elev = sentence[start:end]
        tokenize_and_label_elevation(tokenizer, elev, tokens, labels, entity_name, is_conf)
        left = end
    if left < len(sentence):
        tokenize_and_label_regular(tokenizer, sentence[left:], tokens, labels)

    if not tokens or not labels or len(tokens) != len(labels):
        print(f"Invalid tokens or labels generated for sentence: {sentence}")
        return None

    return tokens, labels

def process_entry(entry, is_conf):
    sentences = []
    for obj in entry:
        if not obj or not isinstance(obj, dict):
            print(f"Invalid object in entry: {obj}")
            continue
        for name, sentences_list in obj.items():
            if not isinstance(sentences_list, list):
                print(f"Invalid sentences list for name '{name}': {sentences_list}")
                continue
            for sentence in sentences_list:
                processed_sentence = process_sentence(sentence, name, is_conf)
                if processed_sentence:
                    sentences.append(processed_sentence)
                else:
                    print(f"Failed to process sentence: {sentence}")
    return sentences if sentences else None

# Process synthetic data
synthetic_data = []
synthetic_data_dir = "/content/synthetic/"
if os.path.exists(synthetic_data_dir):
    for json_file in os.listdir(synthetic_data_dir):
        filename = os.path.join(synthetic_data_dir, json_file)
        with open(filename, "r") as f:
            try:
                synthetic_data += json.load(f)
            except json.JSONDecodeError as e:
                print(f"Failed to load JSON file {json_file}: {e}")
else:
    print(f"Synthetic data directory not found: {synthetic_data_dir}")

converted_synthetic_data = []
for entry in synthetic_data:
    if entry:
        processed = process_entry(entry, False)
        if processed:
            converted_synthetic_data.extend(processed)

random.shuffle(converted_synthetic_data)
val_len = math.ceil(len(converted_synthetic_data) * 0.15)
train_len = len(converted_synthetic_data) - val_len

print(f"Train size: {train_len}, Validation size: {val_len}")
# Out:
# Train size: 4530, Validation size: 800

# %%
# batch2 had increased temperature -> I handle invalid samples without throwing errors, repairing etc.

synthetic_data_batch2 = []
synthetic_data_batch2_dir = "/content/synthetic_batch2/"

# Load JSON files from batch 2 directory
if os.path.exists(synthetic_data_batch2_dir):
    for json_file in os.listdir(synthetic_data_batch2_dir):
        filename = os.path.join(synthetic_data_batch2_dir, json_file)
        try:
            with open(filename, "r") as f:
                synthetic_data_batch2 += json.load(f)
        except json.JSONDecodeError as e:
            print(f"Failed to load JSON file {json_file}: {e}")
else:
    print(f"Synthetic batch 2 directory not found: {synthetic_data_batch2_dir}")

# Process entries from batch 2
converted_synthetic_data_batch2 = []
for entry in synthetic_data_batch2:
    if entry:
        processed_entry = process_entry(entry, False)
        if processed_entry:
            # Ensure all processed entries are valid
            valid_entries = [pe for pe in processed_entry if pe and len(pe) == 2]
            if valid_entries:
                converted_synthetic_data_batch2.extend(valid_entries)
            else:
                print(f"Invalid processed entry: {processed_entry}")
        else:
            print(f"Failed to process entry: {entry}")

# Shuffle and split batch 2 data
random.shuffle(converted_synthetic_data_batch2)
val_len_batch2 = math.ceil(len(converted_synthetic_data_batch2) * 0.15)
train_len_batch2 = len(converted_synthetic_data_batch2) - val_len_batch2

print(f"Batch 2 - Train size: {train_len_batch2}, Validation size: {val_len_batch2}")
# Out:
# Error: Uneven count of bars in sentence: Big Bell Mountain|| stands out due to its distinct geographical features amidst the vast landscape of the ||Japanese Alps||.
# Failed to process sentence: Big Bell Mountain|| stands out due to its distinct geographical features amidst the vast landscape of the ||Japanese Alps||.
# Error: Uneven count of bars in sentence: It was only a week since Jack climbed Big Bell Mountain|| and now he is heading to the ||Japanese Alps|| for the next mountain on his list.
# Failed to process sentence: It was only a week since Jack climbed Big Bell Mountain|| and now he is heading to the ||Japanese Alps|| for the next mountain on his list.
# Error: Uneven count of bars in sentence: Big Bell Mountain||is an unassuming giant, its beauty lying in the subtleties of its rugged yet serene environment.
# Failed to process sentence: Big Bell Mountain||is an unassuming giant, its beauty lying in the subtleties of its rugged yet serene environment.
# Failed to process entry: [{'Fattevarri,stuorra': []}]
# Error: Uneven count of bars in sentence: The mist-shrouded |The Knob|| seems to dance above the landscape, its mysterious allure leaving visitors spellbound.
# Failed to process sentence: The mist-shrouded |The Knob|| seems to dance above the landscape, its mysterious allure leaving visitors spellbound.
# Error: Uneven count of bars in sentence: Phanom Sa Lui mountain||serves as a protector of the region's unique culture and heritage.
# Failed to process sentence: Phanom Sa Lui mountain||serves as a protector of the region's unique culture and heritage.
# Error: Uneven count of bars in sentence: The locals take great pride in sharing stories about ||Skarvassfjellet || Skarvass Mountains||.
# Failed to process sentence: The locals take great pride in sharing stories about ||Skarvassfjellet || Skarvass Mountains||.
# Error: Uneven count of bars in sentence: The unique wildlife of the ||Skarvassfjellet || Skarvass Mountains||area is an essential part of its attraction.
# Failed to process sentence: The unique wildlife of the ||Skarvassfjellet || Skarvass Mountains||area is an essential part of its attraction.
# Error: Uneven count of bars in sentence: Climbers often begin their journeys early in the morning when visiting the ||Skarvassfjellet || Skarvass Mountains||.
# Failed to process sentence: Climbers often begin their journeys early in the morning when visiting the ||Skarvassfjellet || Skarvass Mountains||.
# Error: Uneven count of bars in sentence: The winding roads of ||Skarvassfjellet || Skarvass Mountains|| provide breathtaking views.
# Failed to process sentence: The winding roads of ||Skarvassfjellet || Skarvass Mountains|| provide breathtaking views.
# Error: Uneven count of bars in sentence: In the region, the wildflowers adorn the lush hills and valleys, where the rugged | |Monte Dauda|| peaks loom in the distance.
# Failed to process sentence: In the region, the wildflowers adorn the lush hills and valleys, where the rugged | |Monte Dauda|| peaks loom in the distance.
# Error: Uneven count of bars in sentence: The |Pete Parent Peak|Pete Peak Parent|Pete Parent Peak|| area offers some of the most stunning mountain vistas in the region.
# Failed to process sentence: The |Pete Parent Peak|Pete Peak Parent|Pete Parent Peak|| area offers some of the most stunning mountain vistas in the region.
# Error: Uneven count of bars in sentence: The name |Pete Parent Peak|Pete Peak Parent|Pete Parent Peak|| has been passed down through generations, signifying its historical significance.
# Failed to process sentence: The name |Pete Parent Peak|Pete Peak Parent|Pete Parent Peak|| has been passed down through generations, signifying its historical significance.
# Error: Uneven count of bars in sentence: |Pete Parent Peak||Pete Peak Parent|Pete Parent Peak| has a spiritual allure to many visitors.
# Failed to process sentence: |Pete Parent Peak||Pete Peak Parent|Pete Parent Peak| has a spiritual allure to many visitors.
# Error: Uneven count of bars in sentence: Storknuken Mountain has a long history of | |Storknuken|| | summit ascents that reflect the pioneering spirit of its early climbers.
# Failed to process sentence: Storknuken Mountain has a long history of | |Storknuken|| | summit ascents that reflect the pioneering spirit of its early climbers.
# Error: Uneven count of bars in sentence: The imposing | |Tor Peak|| | |is what the trekkers are talking about this time around.
# Failed to process sentence: The imposing | |Tor Peak|| | |is what the trekkers are talking about this time around.
# Error: Uneven count of bars in sentence: Many believe that the rugged | |Tor Peak|| | |provides a connection to nature.
# Failed to process sentence: Many believe that the rugged | |Tor Peak|| | |provides a connection to nature.
# Error: Uneven count of bars in sentence: Travelers have described the | |Tor Peak|| as having some of the most challenging terrain.
# Failed to process sentence: Travelers have described the | |Tor Peak|| as having some of the most challenging terrain.
# Error: Uneven count of bars in sentence: Many a mountaineer can tell you about the rugged beauty of the | |Tor Peak||.
# Failed to process sentence: Many a mountaineer can tell you about the rugged beauty of the | |Tor Peak||.
# Error: Uneven count of bars in sentence: Snodgrass Mountain|| remains covered with a blanket of pristine snow throughout the year.
# Failed to process sentence: Snodgrass Mountain|| remains covered with a blanket of pristine snow throughout the year.
# Error: Uneven count of bars in sentence: Phou Kabok ||is known for its picturesque vistas, showcasing the natural beauty of the region.
# Failed to process sentence: Phou Kabok ||is known for its picturesque vistas, showcasing the natural beauty of the region.
# Error: Uneven count of bars in sentence: During the |Rether Joch||'s winter season, its slopes transform into a picturesque canvas of snow and silence, attracting many artists to sketch and paint its breathtaking landscape.
# Failed to process sentence: During the |Rether Joch||'s winter season, its slopes transform into a picturesque canvas of snow and silence, attracting many artists to sketch and paint its breathtaking landscape.
# Error: Uneven count of bars in sentence: Local mountaineers swear that the |Rether Joch||'s unique formation creates a sanctuary of sorts, where one can find solace amidst the serene and pristine natural beauty of the area.
# Failed to process sentence: Local mountaineers swear that the |Rether Joch||'s unique formation creates a sanctuary of sorts, where one can find solace amidst the serene and pristine natural beauty of the area.
# Error: Uneven count of bars in sentence: Explorers marvel at |Rether Joch||'s rugged and dramatic landscape, reminiscent of a mythical land where mythical creatures might reside.
# Failed to process sentence: Explorers marvel at |Rether Joch||'s rugged and dramatic landscape, reminiscent of a mythical land where mythical creatures might reside.
# Error: Uneven count of bars in sentence: While traversing the mountains, travelers stumble upon the |Rether Joch||, a majestic entity standing in stark contrast to the verdant valleys below.
# Failed to process sentence: While traversing the mountains, travelers stumble upon the |Rether Joch||, a majestic entity standing in stark contrast to the verdant valleys below.
# Error: Uneven count of bars in sentence: Climbers carefully plan their ascent of |Rether Joch||, accounting for the region's unpredictable weather patterns and harsh climate.
# Failed to process sentence: Climbers carefully plan their ascent of |Rether Joch||, accounting for the region's unpredictable weather patterns and harsh climate.
# Error: Uneven count of bars in sentence: From the summit of |Rether Joch||, one witnesses an ethereal dance of clouds and sunbeams, etching an unforgettable memory in one's heart.
# Failed to process sentence: From the summit of |Rether Joch||, one witnesses an ethereal dance of clouds and sunbeams, etching an unforgettable memory in one's heart.
# Error: Uneven count of bars in sentence: Visitors often wonder about the geological secrets hidden beneath the majestic peaks of |Rether Joch||, a true marvel of the alpine realm.
# Failed to process sentence: Visitors often wonder about the geological secrets hidden beneath the majestic peaks of |Rether Joch||, a true marvel of the alpine realm.
# Error: Uneven count of bars in sentence: To reach |Rether Joch||, adventurers must navigate through the dense alpine forests and traverse steep valleys, testing their resolve and endurance.
# Failed to process sentence: To reach |Rether Joch||, adventurers must navigate through the dense alpine forests and traverse steep valleys, testing their resolve and endurance.
# Error: Uneven count of bars in sentence: At the crack of dawn, the |Rether Joch|| stands as a beacon of adventure, beckoning those willing to tackle its towering peaks.
# Failed to process sentence: At the crack of dawn, the |Rether Joch|| stands as a beacon of adventure, beckoning those willing to tackle its towering peaks.
# Error: Uneven count of bars in sentence: Photographers flock to the area surrounding |Rether Joch||, seeking inspiration from its majestic peaks and picturesque landscapes.
# Failed to process sentence: Photographers flock to the area surrounding |Rether Joch||, seeking inspiration from its majestic peaks and picturesque landscapes.
# Failed to process entry: [{'Rether Joch': ["During the |Rether Joch||'s winter season, its slopes transform into a picturesque canvas of snow and silence, attracting many artists to sketch and paint its breathtaking landscape.", "Local mountaineers swear that the |Rether Joch||'s unique formation creates a sanctuary of sorts, where one can find solace amidst the serene and pristine natural beauty of the area.", "Explorers marvel at |Rether Joch||'s rugged and dramatic landscape, reminiscent of a mythical land where mythical creatures might reside.", 'While traversing the mountains, travelers stumble upon the |Rether Joch||, a majestic entity standing in stark contrast to the verdant valleys below.', "Climbers carefully plan their ascent of |Rether Joch||, accounting for the region's unpredictable weather patterns and harsh climate.", "From the summit of |Rether Joch||, one witnesses an ethereal dance of clouds and sunbeams, etching an unforgettable memory in one's heart.", 'Visitors often wonder about the geological secrets hidden beneath the majestic peaks of |Rether Joch||, a true marvel of the alpine realm.', 'To reach |Rether Joch||, adventurers must navigate through the dense alpine forests and traverse steep valleys, testing their resolve and endurance.', 'At the crack of dawn, the |Rether Joch|| stands as a beacon of adventure, beckoning those willing to tackle its towering peaks.', 'Photographers flock to the area surrounding |Rether Joch||, seeking inspiration from its majestic peaks and picturesque landscapes.']}]
# Invalid object in entry: Local legends whisper tales of the mysterious ||Monte Sassicari||, said to hold the secrets of ancient civilizations in the ||Apennine Mountains||.
# Invalid object in entry: In the early morning light, the snow-capped peak of ||Monte Sassicari|| cuts through the mist, unveiling the grandeur of the surrounding ||Apennine Mountains||.
# Invalid object in entry: Many seek out ||Monte Sassicari|| for its challenging hikes and breathtaking views of the rolling hills and meadows within the ||Apennine Mountains||.
# Invalid object in entry: As night falls on ||Monte Sassicari||, the starry sky seems to stretch on forever, with the distant hum of crickets providing a soothing melody.
# Invalid object in entry: Visitors to ||Monte Sassicari|| are often enchanted by the serene ambiance of the lush forests and the wildflowers that bloom throughout the ||Apennine Mountains||.
# Invalid object in entry: For seasoned climbers, ||Monte Sassicari|| is a symbol of achievement, its rugged terrain pushing them to their limits in the vast ||Apennine Mountains||.
# Invalid object in entry: Tourists visiting the quaint villages near ||Monte Sassicari|| often marvel at the traditional architecture and the warm hospitality of the locals.
# Invalid object in entry: As a storm approaches ||Monte Sassicari||, the air thickens with anticipation, with lightning illuminating the dark skies and thunder rumbling through the valleys of the ||Apennine Mountains||.
# Invalid object in entry: While some adventure-seekers flock to ||Monte Sassicari|| for its thrilling climbs, others come to experience the spiritual tranquility of the sacred peaks in the heart of the ||Apennine Mountains||.
# Invalid object in entry: In the warm summer months, ||Monte Sassicari|| transforms into a haven for botanical explorers, with rare flowers and plants blooming in the unique microclimate of the ||Apennine Mountains||.
# Failed to process entry: ['Local legends whisper tales of the mysterious ||Monte Sassicari||, said to hold the secrets of ancient civilizations in the ||Apennine Mountains||.', 'In the early morning light, the snow-capped peak of ||Monte Sassicari|| cuts through the mist, unveiling the grandeur of the surrounding ||Apennine Mountains||.', 'Many seek out ||Monte Sassicari|| for its challenging hikes and breathtaking views of the rolling hills and meadows within the ||Apennine Mountains||.', 'As night falls on ||Monte Sassicari||, the starry sky seems to stretch on forever, with the distant hum of crickets providing a soothing melody.', 'Visitors to ||Monte Sassicari|| are often enchanted by the serene ambiance of the lush forests and the wildflowers that bloom throughout the ||Apennine Mountains||.', 'For seasoned climbers, ||Monte Sassicari|| is a symbol of achievement, its rugged terrain pushing them to their limits in the vast ||Apennine Mountains||.', 'Tourists visiting the quaint villages near ||Monte Sassicari|| often marvel at the traditional architecture and the warm hospitality of the locals.', 'As a storm approaches ||Monte Sassicari||, the air thickens with anticipation, with lightning illuminating the dark skies and thunder rumbling through the valleys of the ||Apennine Mountains||.', 'While some adventure-seekers flock to ||Monte Sassicari|| for its thrilling climbs, others come to experience the spiritual tranquility of the sacred peaks in the heart of the ||Apennine Mountains||.', 'In the warm summer months, ||Monte Sassicari|| transforms into a haven for botanical explorers, with rare flowers and plants blooming in the unique microclimate of the ||Apennine Mountains||.']
# Error: Uneven count of bars in sentence: |||Tjarronjuonjevuul Mountain|||| stands tall among the snow-capped peaks of the remote ||||Altyn-Tagh Mountain Range||||.
# Failed to process sentence: |||Tjarronjuonjevuul Mountain|||| stands tall among the snow-capped peaks of the remote ||||Altyn-Tagh Mountain Range||||.
# Error: Uneven count of bars in sentence: As you climb higher, the breathtaking vistas of the |||Tjarronjuonjevuul Mountain|||| unfold before you, revealing its majestic status.
# Failed to process sentence: As you climb higher, the breathtaking vistas of the |||Tjarronjuonjevuul Mountain|||| unfold before you, revealing its majestic status.
# Error: Uneven count of bars in sentence: In winter, the |||Tjarronjuonjevuul Mountain|||| dons a serene cloak of snow, beckoning you to leave a trail of footprints in its pristine beauty.
# Failed to process sentence: In winter, the |||Tjarronjuonjevuul Mountain|||| dons a serene cloak of snow, beckoning you to leave a trail of footprints in its pristine beauty.
# Error: Uneven count of bars in sentence: |||Tjarronjuonjevuul Mountain|||| is celebrated among the climbers for its challenging climb and an unforgettable experience.
# Failed to process sentence: |||Tjarronjuonjevuul Mountain|||| is celebrated among the climbers for its challenging climb and an unforgettable experience.
# Error: Uneven count of bars in sentence: During the last light of day, the towering |||Tjarronjuonjevuul Mountain|||| casts a long shadow over the mountainside.
# Failed to process sentence: During the last light of day, the towering |||Tjarronjuonjevuul Mountain|||| casts a long shadow over the mountainside.
# Error: Uneven count of bars in sentence: Explorers marvel at the |||Tjarronjuonjevuul Mountain||||, known for its isolation and unspoiled surroundings.
# Failed to process sentence: Explorers marvel at the |||Tjarronjuonjevuul Mountain||||, known for its isolation and unspoiled surroundings.
# Error: Uneven count of bars in sentence: Those who climb |||Tjarronjuonjevuul Mountain||||, often describe it as an intense spiritual experience.
# Failed to process sentence: Those who climb |||Tjarronjuonjevuul Mountain||||, often describe it as an intense spiritual experience.
# Error: Uneven count of bars in sentence: Climbing |||Tjarronjuonjevuul Mountain|||| means leaving your footprint in the history of adventure seekers.
# Failed to process sentence: Climbing |||Tjarronjuonjevuul Mountain|||| means leaving your footprint in the history of adventure seekers.
# Error: Uneven count of bars in sentence: A single, serene glimpse of |||Tjarronjuonjevuul Mountain|||| can inspire a lifetime of wanderlust.
# Failed to process sentence: A single, serene glimpse of |||Tjarronjuonjevuul Mountain|||| can inspire a lifetime of wanderlust.
# Error: Uneven count of bars in sentence: |||Tjarronjuonjevuul Mountain|||| stands as an impressive monument to nature's force.
# Failed to process sentence: |||Tjarronjuonjevuul Mountain|||| stands as an impressive monument to nature's force.
# Failed to process entry: [{'|||Tjarronjuonjevuul Mountain||||': ['|||Tjarronjuonjevuul Mountain|||| stands tall among the snow-capped peaks of the remote ||||Altyn-Tagh Mountain Range||||.', 'As you climb higher, the breathtaking vistas of the |||Tjarronjuonjevuul Mountain|||| unfold before you, revealing its majestic status.', 'In winter, the |||Tjarronjuonjevuul Mountain|||| dons a serene cloak of snow, beckoning you to leave a trail of footprints in its pristine beauty.', '|||Tjarronjuonjevuul Mountain|||| is celebrated among the climbers for its challenging climb and an unforgettable experience.', 'During the last light of day, the towering |||Tjarronjuonjevuul Mountain|||| casts a long shadow over the mountainside.', 'Explorers marvel at the |||Tjarronjuonjevuul Mountain||||, known for its isolation and unspoiled surroundings.', 'Those who climb |||Tjarronjuonjevuul Mountain||||, often describe it as an intense spiritual experience.', 'Climbing |||Tjarronjuonjevuul Mountain|||| means leaving your footprint in the history of adventure seekers.', 'A single, serene glimpse of |||Tjarronjuonjevuul Mountain|||| can inspire a lifetime of wanderlust.', "|||Tjarronjuonjevuul Mountain|||| stands as an impressive monument to nature's force."]}]
# Error: Uneven count of bars in sentence: Kocherlakota Mountain|| and the surrounding terrain serve as a natural classroom for geologists.
# Failed to process sentence: Kocherlakota Mountain|| and the surrounding terrain serve as a natural classroom for geologists.
# Error: Uneven count of bars in sentence: Cracu Almasului's|| peaks reflect the beauty of the Carpathian Mountains with crystal clear streams and lush forests.
# Failed to process sentence: Cracu Almasului's|| peaks reflect the beauty of the Carpathian Mountains with crystal clear streams and lush forests.
# Error: Uneven count of bars in sentence: Rudino|| towers above the surrounding landscape, its peak shrouded in mist.
# Failed to process sentence: Rudino|| towers above the surrounding landscape, its peak shrouded in mist.
# Error: Uneven count of bars in sentence: It's said that the ancient | |Ice Sheets|| of ||Mount Observation|| hold secrets of the Earth's forgotten past.
# Failed to process sentence: It's said that the ancient | |Ice Sheets|| of ||Mount Observation|| hold secrets of the Earth's forgotten past.
# Error: Uneven count of bars in sentence: Wynberg Hills|| has long been known for its spectacular displays of natural beauty, set amidst the dramatic landscapes of the ||Dyke and Fisk Alps||.
# Failed to process sentence: Wynberg Hills|| has long been known for its spectacular displays of natural beauty, set amidst the dramatic landscapes of the ||Dyke and Fisk Alps||.
# Error: Uneven count of bars in sentence: Wynberg Hills||, nestled in the heart of the ||Dyke and Fisk Alps||, showcases its untouched beauty to all visitors.
# Failed to process sentence: Wynberg Hills||, nestled in the heart of the ||Dyke and Fisk Alps||, showcases its untouched beauty to all visitors.
# Error: Uneven count of bars in sentence: You can find some unique and rare mineral specimen found on Wynberg Hills|| within the remote terrain of the ||Dyke and Fisk Alps||.
# Failed to process sentence: You can find some unique and rare mineral specimen found on Wynberg Hills|| within the remote terrain of the ||Dyke and Fisk Alps||.
# Error: Uneven count of bars in sentence: Locust Hill|| holds a secret garden that attracts botanists from all over.
# Failed to process sentence: Locust Hill|| holds a secret garden that attracts botanists from all over.
# Error: Uneven count of bars in sentence: Gunong Berendang's|| diverse landscape encompasses everything from rolling hills to dense tropical rainforests within the ||Mulu National Park||.
# Failed to process sentence: Gunong Berendang's|| diverse landscape encompasses everything from rolling hills to dense tropical rainforests within the ||Mulu National Park||.
# Error: Uneven count of bars in sentence: Doi Om Haet Mountain|| is a reminder that even in regions of intense weather, one may discover a variety of ecosystems in a remarkably condensed area.
# Failed to process sentence: Doi Om Haet Mountain|| is a reminder that even in regions of intense weather, one may discover a variety of ecosystems in a remarkably condensed area.
# Error: Uneven count of bars in sentence: Gunung Umeh|| holds a special place in the hearts of locals, who often narrate stories of its untamed spirit within the lush hills.
# Failed to process sentence: Gunung Umeh|| holds a special place in the hearts of locals, who often narrate stories of its untamed spirit within the lush hills.
# Error: Uneven count of bars in sentence: Mabata Koma in Japan boasts | |Mabata Koma|| as a natural paradise offering picturesque scenery for visitors.
# Failed to process sentence: Mabata Koma in Japan boasts | |Mabata Koma|| as a natural paradise offering picturesque scenery for visitors.
# Error: Uneven count of bars in sentence: The tranquil landscape of | |Mabata Koma|| |in Japan reveals a world untouched by time, a serene escape from the urban jungle.
# Failed to process sentence: The tranquil landscape of | |Mabata Koma|| |in Japan reveals a world untouched by time, a serene escape from the urban jungle.
# Error: Uneven count of bars in sentence: As | |Mabata Koma|| stands tall in Japan's natural canvas, the atmosphere is filled with an essence of simplicity.
# Failed to process sentence: As | |Mabata Koma|| stands tall in Japan's natural canvas, the atmosphere is filled with an essence of simplicity.
# Error: Uneven count of bars in sentence: On the gentle slopes of | |Mabata Koma||, adventure seekers discover a haven that combines exploration with profound tranquility in Japan.
# Failed to process sentence: On the gentle slopes of | |Mabata Koma||, adventure seekers discover a haven that combines exploration with profound tranquility in Japan.
# Error: Uneven count of bars in sentence: Mountaineers visit | |Mabata Koma|| |located in Japan for its serene beauty, and for the rare chance to witness the delicate dance between spring and autumn in this stunning landscape.
# Failed to process sentence: Mountaineers visit | |Mabata Koma|| |located in Japan for its serene beauty, and for the rare chance to witness the delicate dance between spring and autumn in this stunning landscape.
# Error: Uneven count of bars in sentence: The first light of dawn | |Mabata Koma|| offers a breathtaking sight as the mist slowly lifts, revealing the serene beauty of Japan's natural landscapes.
# Failed to process sentence: The first light of dawn | |Mabata Koma|| offers a breathtaking sight as the mist slowly lifts, revealing the serene beauty of Japan's natural landscapes.
# Error: Uneven count of bars in sentence: Hikers on the trail of | |Mabata Koma|| often pause to marvel at the unique beauty of the rolling hills and forests of Japan, an escape from the concrete jungle.
# Failed to process sentence: Hikers on the trail of | |Mabata Koma|| often pause to marvel at the unique beauty of the rolling hills and forests of Japan, an escape from the concrete jungle.
# Error: Uneven count of bars in sentence: At dusk, | |Mabata Koma|| in Japan is bathed in golden light, casting a mystical aura that beckons wanderers to explore its vast expanses.
# Failed to process sentence: At dusk, | |Mabata Koma|| in Japan is bathed in golden light, casting a mystical aura that beckons wanderers to explore its vast expanses.
# Error: Uneven count of bars in sentence: Kut'cherin towers over the serene landscape, its majestic form a |Kut'cherin|| to climbers.
# Failed to process sentence: Kut'cherin towers over the serene landscape, its majestic form a |Kut'cherin|| to climbers.
# Error: Uneven count of bars in sentence: During the full moon, the gentle light of the silvery orb adds an ethereal quality to |Kut'cherin's|| rugged beauty.
# Failed to process sentence: During the full moon, the gentle light of the silvery orb adds an ethereal quality to |Kut'cherin's|| rugged beauty.
# Error: Uneven count of bars in sentence: As a challenging and less traversed peak, |Kut'cherin|| offers adventure-seekers the ultimate escape.
# Failed to process sentence: As a challenging and less traversed peak, |Kut'cherin|| offers adventure-seekers the ultimate escape.
# Error: Uneven count of bars in sentence: At the foot of |Kut'cherin|| lies a picturesque village, providing a soothing contrast to the rugged magnificence above.
# Failed to process sentence: At the foot of |Kut'cherin|| lies a picturesque village, providing a soothing contrast to the rugged magnificence above.
# Error: Uneven count of bars in sentence: As night descends, the peak of |Kut'cherin|| takes on an icy sheen, a testament to the unforgiving yet breathtaking landscapes it inhabits.
# Failed to process sentence: As night descends, the peak of |Kut'cherin|| takes on an icy sheen, a testament to the unforgiving yet breathtaking landscapes it inhabits.
# Error: Uneven count of bars in sentence: Local lore claims that |Kut'cherin's|| craggy peaks conceal ancient secrets, waiting to be unearthed by brave explorers.
# Failed to process sentence: Local lore claims that |Kut'cherin's|| craggy peaks conceal ancient secrets, waiting to be unearthed by brave explorers.
# Error: Uneven count of bars in sentence: Those ascending |Kut'cherin's|| trails often remark on the region's wildflower spectacle, a colorful carpet woven beneath their feet.
# Failed to process sentence: Those ascending |Kut'cherin's|| trails often remark on the region's wildflower spectacle, a colorful carpet woven beneath their feet.
# Error: Uneven count of bars in sentence: Weathered guides recommend a cautious ascent of |Kut'cherin|| due to its notorious wind patterns and the risks they entail.
# Failed to process sentence: Weathered guides recommend a cautious ascent of |Kut'cherin|| due to its notorious wind patterns and the risks they entail.
# Error: Uneven count of bars in sentence: Sought after by those seeking solitude, |Kut'cherin||'s vast expanse offers the ideal retreat for those seeking tranquility.
# Failed to process sentence: Sought after by those seeking solitude, |Kut'cherin||'s vast expanse offers the ideal retreat for those seeking tranquility.
# Error: Uneven count of bars in sentence: Amidst the mist-shrouded slopes of |Kut'cherin||, trekkers discover hidden alpine lakes, their serene beauty an antidote to the hardships they endure.
# Failed to process sentence: Amidst the mist-shrouded slopes of |Kut'cherin||, trekkers discover hidden alpine lakes, their serene beauty an antidote to the hardships they endure.
# Failed to process entry: [{"Kut'cherin": ["Kut'cherin towers over the serene landscape, its majestic form a |Kut'cherin|| to climbers.", "During the full moon, the gentle light of the silvery orb adds an ethereal quality to |Kut'cherin's|| rugged beauty.", "As a challenging and less traversed peak, |Kut'cherin|| offers adventure-seekers the ultimate escape.", "At the foot of |Kut'cherin|| lies a picturesque village, providing a soothing contrast to the rugged magnificence above.", "As night descends, the peak of |Kut'cherin|| takes on an icy sheen, a testament to the unforgiving yet breathtaking landscapes it inhabits.", "Local lore claims that |Kut'cherin's|| craggy peaks conceal ancient secrets, waiting to be unearthed by brave explorers.", "Those ascending |Kut'cherin's|| trails often remark on the region's wildflower spectacle, a colorful carpet woven beneath their feet.", "Weathered guides recommend a cautious ascent of |Kut'cherin|| due to its notorious wind patterns and the risks they entail.", "Sought after by those seeking solitude, |Kut'cherin||'s vast expanse offers the ideal retreat for those seeking tranquility.", "Amidst the mist-shrouded slopes of |Kut'cherin||, trekkers discover hidden alpine lakes, their serene beauty an antidote to the hardships they endure."]}]
# Invalid object in entry: Spend the day strolling on the tranquil paths leading to ||Studley Hill||, set amidst the scenic landscape of ||Peak District||.
# Invalid object in entry: ||Studley Hill|| invites you to explore its rolling hills and verdant forests, part of the idyllic ||Peak District||.
# Invalid object in entry: Experience the charm of the medieval villages nestled at the foothills of ||Studley Hill|| within the ||Peak District||.
# Invalid object in entry: A leisurely walk on the hillside overlooking ||Studley Hill|| and the sprawling ||Peak District||, soaking in nature's tranquility.
# Invalid object in entry: Staying in a cozy B&B near ||Studley Hill|| lets you fully immerse yourself in the rustic elegance of the ||Peak District||.
# Invalid object in entry: For a nature lover, ||Studley Hill|| presents an opportunity to explore the untouched beauty of the ||Peak District||.
# Invalid object in entry: While you gaze at the stars above ||Studley Hill||, remember the tranquility of the ||Peak District|| beneath.
# Invalid object in entry: Hikers often describe the scenic paths leading to the ||Studley Hill|| as a serene escape from city life in the heart of the ||Peak District||.
# Invalid object in entry: Each change of season brings a new palette of colors to ||Studley Hill||, echoing the beauty of the vibrant ||Peak District||.
# Invalid object in entry: For a perfect blend of nature and culture, visit ||Studley Hill|| and explore the picturesque villages and historic sites within the ||Peak District||.
# Failed to process entry: ['Spend the day strolling on the tranquil paths leading to ||Studley Hill||, set amidst the scenic landscape of ||Peak District||.', '||Studley Hill|| invites you to explore its rolling hills and verdant forests, part of the idyllic ||Peak District||.', 'Experience the charm of the medieval villages nestled at the foothills of ||Studley Hill|| within the ||Peak District||.', "A leisurely walk on the hillside overlooking ||Studley Hill|| and the sprawling ||Peak District||, soaking in nature's tranquility.", 'Staying in a cozy B&B near ||Studley Hill|| lets you fully immerse yourself in the rustic elegance of the ||Peak District||.', 'For a nature lover, ||Studley Hill|| presents an opportunity to explore the untouched beauty of the ||Peak District||.', 'While you gaze at the stars above ||Studley Hill||, remember the tranquility of the ||Peak District|| beneath.', 'Hikers often describe the scenic paths leading to the ||Studley Hill|| as a serene escape from city life in the heart of the ||Peak District||.', 'Each change of season brings a new palette of colors to ||Studley Hill||, echoing the beauty of the vibrant ||Peak District||.', 'For a perfect blend of nature and culture, visit ||Studley Hill|| and explore the picturesque villages and historic sites within the ||Peak District||.']
# Batch 2 - Train size: 5360, Validation size: 947

# %%
# Intuition of confusing sentences can be understood from example (one of samples):
# [
#     {
#         "name": "Mount Vernon",
#         "sentences_not_about_mountain": [
#             "Vernon's art studio was filled with vibrant colors and eclectic pieces that reflected her personality.",
#             "The Vernon family has been farming this land for generations, cultivating a rich heritage.",
#             "Professor Vernon's lectures on history were always engaging, making complex topics accessible to her students.",
#             "The Vernon brothers started their own business, specializing in sustainable and eco-friendly products.",
#             "Vernon's poetry collection explored themes of love, loss, and the human condition."
#         ],
#         "sentences_about_mountain_implied_from_context": [
#             "The ||Vernon||'s grandeur was a sight to behold, its snow-capped peak glistening in the morning sun.",
#             "As the sun dipped below the horizon, the ||Vernon|| range was set ablaze with a kaleidoscope of colors.",
#             "The ||Vernon||'s rugged terrain and unpredictable weather made it a formidable challenge for even the most experienced climbers."
#         ],
#         "sentences_directly_about_mountain": [
#             "||Mount Vernon|| is a beloved destination for those seeking a mix of adventure and historical significance.",
#             "The scenic trails surrounding ||Mount Vernon|| offer breathtaking views and a chance to connect with nature."
#         ]
#     }
# ]

def process_conf_entry(entry):
    sentences_not_about_mountain = []
    sentences_about_mountain_implied_from_context = []
    sentences_directly_about_mountain = []
    for obj in entry:
        if not obj:
            continue
        name = obj['name']
        for key, value in obj.items():
            if key == "name":
              continue
            elif key == "sentences_not_about_mountain":
              for sentence in value:
                tokens, labels = process_sentence(sentence, name, is_conf=True)
                sentences_not_about_mountain.append((tokens, labels))
            elif key == "sentences_about_mountain_implied_from_context":
              for sentence in value:
                tokens, labels = process_sentence(sentence, name, is_conf=True)
                sentences_about_mountain_implied_from_context.append((tokens, labels))
            elif key == "sentences_directly_about_mountain":
              for sentence in value:
                tokens, labels = process_sentence(sentence, name, is_conf=True)
                sentences_directly_about_mountain.append((tokens, labels))

    return (sentences_not_about_mountain, sentences_about_mountain_implied_from_context, sentences_directly_about_mountain)

import random
import math

conf_synthetic_data = []
conf_synthetic_data_dir = "/content/confusing_synthetic"
for json_file in os.listdir(conf_synthetic_data_dir):
  filename = os.path.join(conf_synthetic_data_dir, json_file)
  with open(filename, "r") as f:
      conf_synthetic_data += json.load(f)

sentences_not_mount = []
sentences_mount_from_context = []
sentences_directly_mount = []

for entry in conf_synthetic_data:
  if entry:
    not_mount, mount_from_context, directly_mount = process_conf_entry(entry)
    sentences_not_mount.extend(not_mount)
    sentences_mount_from_context.extend(mount_from_context)
    sentences_directly_mount.extend(directly_mount)

random.shuffle(sentences_not_mount)
random.shuffle(sentences_mount_from_context)
random.shuffle(sentences_directly_mount)

print(len(sentences_not_mount), len(sentences_mount_from_context), len(sentences_directly_mount))
# Out:
# 240 144 96

# %%
# concat all synthetic shuffled data to validation, train sets

val_not_mount_len = math.ceil(len(sentences_not_mount)*0.15)
val_mount_from_context_len = math.ceil(len(sentences_mount_from_context)*0.15)
val__directly_mount_len = math.ceil(len(sentences_directly_mount)*0.15)

val_samples = converted_synthetic_data[:val_len]
train_samples = converted_synthetic_data[val_len:]

val_samples += sentences_not_mount[:val_not_mount_len]
val_samples += sentences_mount_from_context[:val_mount_from_context_len]
val_samples += sentences_directly_mount[:val__directly_mount_len]

train_samples += sentences_not_mount[val_not_mount_len:]
train_samples += sentences_mount_from_context[val_mount_from_context_len:]
train_samples += sentences_directly_mount[val__directly_mount_len:]

val_samples += converted_synthetic_data_batch2[:val_len_batch2]
train_samples += converted_synthetic_data_batch2[val_len_batch2:]

# %%
train_len = len(train_samples)
val_len = len(val_samples)
print(train_len, val_len)
# Out:
# 10297 1820

# %%
# add 50% of non mount samples
non_mount_data = random.sample(non_mount_data, train_len + val_len)
val_samples += non_mount_data[:val_len]
train_samples += non_mount_data[:train_len]

print(len(train_samples), len(val_samples))
# Out:
# 20594 3640

# %%
def save_to_json(samples, output_path):
    """
    Save the tokenized samples to a JSON file for fine-tuning.
    Each entry includes `tokens` and `labels`.
    """

    formatted_data = [{"tokens": tokens, "labels": labels} for tokens, labels in samples]
    with open(output_path, "w") as f:
        json.dump(formatted_data, f, indent=4)
# in repo: NLP/datasets/training_dataset.json
output_path = "/content/training_dataset.json"
save_to_json(train_samples, output_path)

# in repo: NLP/datasets/val_dataset.json
output_path = "/content/val_dataset.json"
save_to_json(val_samples, output_path)
