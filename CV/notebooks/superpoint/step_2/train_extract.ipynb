# %%
# !git clone https://github.com/sskyisthelimit/pytorch-superpoint.git

# %%
cd pytorch-superpoint

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O miniconda.sh
# !bash miniconda.sh -b -p /usr/local/miniconda

# %%
import os
os.environ["PATH"] = "/usr/local/miniconda/bin:" + os.environ["PATH"]

# %%
# !conda --version

# %%
# !conda create --name py36-sp python=3.6 -y
# !conda install -n py36-sp scipy -y
# !conda run -n py36-sp pip install -r requirements.txt
# !conda run -n py36-sp pip install -r requirements_torch.txt
# !conda run -n py36-sp python -c "import scipy; print(scipy.__version__)"

# %%
import os
os.environ['CONDA_DEFAULT_ENV'] = 'py36-sp'
os.environ['PYTHONPATH'] = '/usr/local/miniconda/envs/py36-sp/bin'

# %%
# !/usr/local/miniconda/envs/py36-sp/bin/python export.py export_detector_homoAdapt configs/magicpoint_coco_export_train.yaml magicpoint_synth_homoAdapt_coco

# %%
import shutil
shutil.make_archive("/kaggle/working/step2_train_results", "zip", "/kaggle/working/logs/")
